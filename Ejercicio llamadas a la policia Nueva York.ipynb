# %%
import pandas as pd
import matplotlib as mpl
from matplotlib import pyplot as plt
# %matplotlib inline

plt.style.use(['fivethirtyeight'])
mpl.rcParams['lines.linewidth'] = 3

# %%
# !ls -l /home/ainhoa/Master/311_calls.csv.zip
# Out:
# -rw-r--r-- 1 ainhoa ainhoa 32916981 ene 12 10:00 /home/ainhoa/Master/311_calls.csv.zip

# %%
#Vamos a ver qué pinta tiene este dataset:
! zcat /home/ainhoa/Master/311_calls.csv.zip | head -3
# Out:
# Unique Key,Created Date,Closed Date,Agency,Agency Name,Complaint Type,Descriptor,Location Type,Incident Zip,Incident Address,Street Name,Cross Street 1,Cross Street 2,Intersection Street 1,Intersection Street 2,Address Type,City,Landmark,Facility Type,Status,Due Date,Resolution Description,Resolution Action Updated Date,Community Board,Borough,X Coordinate (State Plane),Y Coordinate (State Plane),Park Facility Name,Park Borough,School Name,School Number,School Region,School Code,School Phone Number,School Address,School City,School State,School Zip,School Not Found,School or Citywide Complaint,Vehicle Type,Taxi Company Borough,Taxi Pick Up Location,Bridge Highway Name,Bridge Highway Direction,Road Ramp,Bridge Highway Segment,Garage Lot Name,Ferry Direction,Ferry Terminal Name,Latitude,Longitude,Location
# ...

# %%
req_df = pd.read_csv('/home/ainhoa/Master/311_calls.csv.zip', header=0, sep=',', parse_dates=['Created Date', 'Closed Date'], dayfirst=False, index_col='Created Date')
req_df
# Out:
#                      Unique Key         Closed Date Agency  \
# Created Date
# 2015-12-31 23:59:45    32310363 2016-01-01 00:55:15   NYPD
# 2015-12-31 23:59:44    32309934 2016-01-01 01:26:57   NYPD
# 2015-12-31 23:59:29    32309159 2016-01-01 04:51:03   NYPD
# 2015-12-31 23:57:46    32305098 2016-01-01 07:43:13   NYPD
# 2015-12-31 23:56:58    32306529 2016-01-01 03:24:42   NYPD
# 2015-12-31 23:56:30    32306554 2016-01-01 01:50:11   NYPD
# 2015-12-31 23:55:32    32306559 2016-01-01 01:53:54   NYPD
# 2015-12-31 23:54:05    32307009 2016-01-01 01:42:54   NYPD
# 2015-12-31 23:53:58    32308581 2016-01-01 08:27:32   NYPD
# 2015-12-31 23:53:58    32308391 2016-01-01 01:17:40   NYPD
# 2015-12-31 23:52:58    32305071 2016-01-01 07:41:38   NYPD
# 2015-12-31 23:50:57    32306260 2016-01-01 10:58:08   NYPD
# 2015-12-31 23:48:03    32306612 2016-01-01 02:17:59   NYPD
# 2015-12-31 23:47:58    32305074 2016-01-01 08:18:47   NYPD
# 2015-12-31 23:47:37    32309424 2016-01-01 10:17:22   NYPD
# ...

# %%
req_df.shape
# Out:
# (364558, 52)

# %%
req_df['Complaint Type']
# Out:
# Created Date
# 2015-12-31 23:59:45     Noise - Street/Sidewalk
# 2015-12-31 23:59:44            Blocked Driveway
# 2015-12-31 23:59:29            Blocked Driveway
# 2015-12-31 23:57:46             Illegal Parking
# 2015-12-31 23:56:58             Illegal Parking
# 2015-12-31 23:56:30             Illegal Parking
# 2015-12-31 23:55:32             Illegal Parking
# 2015-12-31 23:54:05            Blocked Driveway
# 2015-12-31 23:53:58             Illegal Parking
# 2015-12-31 23:53:58            Blocked Driveway
# 2015-12-31 23:52:58            Blocked Driveway
# 2015-12-31 23:50:57            Blocked Driveway
# 2015-12-31 23:48:03     Noise - Street/Sidewalk
# 2015-12-31 23:47:58             Illegal Parking
# 2015-12-31 23:47:37            Derelict Vehicle
# 2015-12-31 23:47:30            Blocked Driveway
# 2015-12-31 23:47:02            Blocked Driveway
# 2015-12-31 23:44:52          Noise - Commercial
# 2015-12-31 23:40:59          Noise - Commercial
# ...

# %%
req_df['Complaint Type'].value_counts()
# Out:
# Blocked Driveway             100881
# Illegal Parking               92679
# Noise - Street/Sidewalk       51692
# Noise - Commercial            44109
# Derelict Vehicle              21661
# Noise - Vehicle               19352
# Animal Abuse                  10541
# Traffic                        5198
# Homeless Encampment            4879
# Vending                        4192
# Noise - Park                   4109
# Drinking                       1409
# Noise - House of Worship       1070
# Posting Advertisement           681
# Urinating in Public             641
# Bike/Roller/Skate Chronic       478
# Panhandling                     327
# Disorderly Youth                315
# Illegal Fireworks               172
# Graffiti                        157
# Agency Issues                     8
# Squeegee                          4
# Ferry Complaint                   2
# Animal in a Park                  1
# Name: Complaint Type, dtype: int64

# %%
req_df[['Complaint Type', 'Borough']].head()
# Out:
#                               Complaint Type    Borough
# Created Date
# 2015-12-31 23:59:45  Noise - Street/Sidewalk  MANHATTAN
# 2015-12-31 23:59:44         Blocked Driveway     QUEENS
# 2015-12-31 23:59:29         Blocked Driveway      BRONX
# 2015-12-31 23:57:46          Illegal Parking      BRONX
# 2015-12-31 23:56:58          Illegal Parking     QUEENS

# %%
req_df['Complaint Type'].value_counts().plot(kind='barh', figsize=(15, 10))

# %%
req_df['Borough'].value_counts().plot(kind='barh')

# %%
#Si queremos visualizar la localización de los sucesos, utilizamos las coordenadas y un scatter:
req_df.plot(kind='scatter', x='Longitude', y='Latitude', alpha=.1, figsize=(12, 12), s=1)

# %%
req_df[req_df['Borough']=='MANHATTAN'].plot(kind='scatter', x='Longitude', y='Latitude', alpha=.1, figsize=(12, 12), s=1)

# %%
req_df['Borough'].value_counts()
colors = ('lime', 'orange', 'm', 'b', 'pink', 'peru')
fig, ax = plt.subplots(1, 1, figsize=(12, 12))
for color, barrio in zip(colors, req_df['Borough'].value_counts().index):
    req_df[req_df['Borough']==barrio].plot(kind='scatter', c=color, label=barrio, ax=ax, x='Longitude', y='Latitude', alpha=.1, s=1)
plt.legend()

# %%
#Dónde se concentran más las llamadas? Para ver eso, vamos a teselar el plano, haciendo una rejilla:
req_df.plot(kind='hexbin',x='Longitude', y='Latitude', gridsize=80, figsize=(12, 8), colormap='jet')

# %%
#Para descartar zonas enlas que no hay nada de quejas:
req_df.plot(kind='hexbin',x='Longitude', y='Latitude', gridsize=80, figsize=(12, 8), colormap='jet', mincnt=1)

# %% [markdown]
# Se podría superponer un mapa de openstreetmaps a este grafico, para poder ampliar y ver exactamente
# en qué calles hay más problemas. PROBAR A HACER ESTO EN CASA.

# %%
#Si nos queremos ir de fiesta, tendremos que buscar las quejas por ruido:
req_noise_df = req_df[req_df['Complaint Type'].str.contains('noise', case=False)]
req_noise_df.plot(kind='hexbin',x='Longitude', y='Latitude', gridsize=80, figsize=(12, 8), colormap='jet', mincnt=1)

# %%
#Dentro de las quejas por ruido, vamos a seleccionar las que nos interesen:
req_df['Descriptor'].value_counts()
# Out:
# No Access                         75888
# Loud Music/Party                  69708
# Posted Parking Sign Violation     27200
# Partial Access                    24993
# Loud Talking                      23810
# With License Plate                21661
# Blocked Hydrant                   19989
# Commercial Overnight Parking      14997
# Blocked Sidewalk                  13860
# Car/Truck Music                   11940
# Double Parked Blocking Traffic     7164
# Engine Idling                      5323
# Double Parked Blocking Vehicle     5167
# Neglected                          5131
# Banging/Pounding                   4959
# Car/Truck Horn                     4478
# Congestion/Gridlock                3237
# Other (complaint details)          2489
# In Prohibited Area                 2206
# Overnight Commercial Storage       2102
# Unlicensed                         1986
# Unauthorized Bus Layover           1618
# Truck Route Violation              1125
# ...

# %%
req_df[req_df['Complaint Type'] == 'Drinking'].plot(kind='hexbin',x='Longitude', y='Latitude', gridsize=80, figsize=(12, 8), colormap='jet', mincnt=1)

# %%
req_df[req_df['Complaint Type'] == 'Drinking']['Descriptor'].value_counts()
# Out:
# In Public                     971
# Underage - Licensed Est       345
# After Hours - Licensed Est     93
# Name: Descriptor, dtype: int64

# %%
#Si queremos combinar los sitios con música alta y en los que se bebe mucho:
req_party_df = req_df[(req_df['Descriptor'] == 'Loud Music/Party') | (req_df['Descriptor'] == 'After Hours - Licensed Est')]

# %%
req_party_df.plot(kind='hexbin',x='Longitude', y='Latitude', gridsize=40, figsize=(12, 8), colormap='jet', mincnt=1)

# %%
req_party_df.plot(kind='hexbin',x='Longitude', y='Latitude', gridsize=40, figsize=(12, 8), colormap='viridis', mincnt=1)

# %% [markdown]
# Una web muy chula para generar nuestra propia paleta de colores: colorbrewer2.org

# %% [markdown]
# # PROFILING O CÓMO MEJORAR LA EFICIENCIA DE MI CÓDIGO

# %% [markdown]
# Cómo evaluar la eficiencia o el rendimiento de nuestro código.
# Profiling: saber cuánto tiempo y memoria me lleva cada línea de mi código

# %%
#En Jupyter, podemos usar:
#%%timeit para calcular cuánto tiempo tarda cada celda en ejecutarse.
#En la shell de Python, podemos usar "time" + la línea de código para evaluar el tiempo que tarda

# %% [markdown]
# Pyhton tiene también un módulo ('line_profiler') para hacer profiling que se usa para hacer profiling a una función.
# Hay que instalarlo primero, y para llamarlo hay que ponerle antes un @.
# Nos puede evaluar linea a linea cuánto tarda cada una de ellas, y así poder mejorar la eficiencia si podemos
